# %% [markdown]
# # Unet for multi-class segmentation
# Train and predict

# %% [markdown]
# ## Chalange description

# %% [markdown]
# The data is 3D MRI images with 4 channels:
# * Flair
# * T1
# * T1ce
# * T2
# tensorflow
# There are 259 photos in train data, each has segmentation labeling file, with the following lables:
#
# * Label 0: background
# * Label 1: necrotic and non-enhancing tumor
# * Label 2: edema
# * Label 4: enhancing tumor
#
# In the data preprocessing stage, I converted and merged the nii.gz files, to anumpy file of the format:
# > (155, 240, 240, 4)
# > For simplicity, I change label 4 to 3. So we need to change it back, for submitting results to Brats challange.

# %%
import pandas
import numpy
import os, sys, glob
import numpy as np
import SimpleITK as sitk
import sys
import os
import pandas as pd
import re
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage.util.dtype import dtype_range
from skimage.util import img_as_ubyte
from skimage import exposure
from skimage.morphology import disk
from skimage.filters import rank
from scipy.ndimage import gaussian_filter
from skimage import data
from skimage import img_as_float
from skimage.morphology import reconstruction
from scipy import ndimage
import random
from random import randrange
from keras.utils import np_utils
from sklearn.utils import shuffle

# %%
import model_unet
label_type_shrt = ['background', 'necrotic',
             'edema', 'enhancing']
label_type = ['background', 'necrotic and non-enhancing tumor', 'edema', 'enhancing tumor']

# %%
import paths
path_names = paths.set_names()
TEST_PRED_NUMPY_DIR = path_names[8]
VALIDATION_PRED_NUMPY_DIR = path_names[9]
VALIDATION_PRED_NII_DIR = path_names[10]

DATA_HGG = path_names[4]
DATA_LGG = path_names[5]

FLAIR = 'flair'
T1 = 't1'
T2 = 't2'
T1CE = 't1ce'

NUMPY_DIR = path_names[6]
VALIDATION_DATA = path_names[1]
VALIDATION_NUMPY_DIR = path_names[7]

# %%
img_type=['FLAIR', 'T1','T1CE', 'T2']

# %% [markdown]
# ## Visualization utilities

# %%
## used to actual and model predictions visualy
from importlib import reload  # Python 3.4+ only.
import visualization_utils  as vu
from visualization_utils import show_lable_on_image4
reload(vu)
# Out:
# <module 'visualization_utils' from '/Users/nathansimms/PycharmProjects/cmpt340-brain-tumor-detection2/visualization_utils.py'>

# %%
red_multiplier = [1, 0.2, 0.2]
green_multiplier = [0.35,0.75,0.25]
blue_multiplier = [0,0.5,1.] #[0,0.25,0.9]
yellow_multiplier = [1,1,0.25]
brown_miltiplier = [40./255, 26./255, 13./255]
my_colors=[blue_multiplier, yellow_multiplier, brown_miltiplier]

# %%
def show_img_lable(img, lbl, modality = 0):
    if (len(lbl.shape)> 2):
        lbl[0,0,3]=1 # for uniqe colors in plot
        lbl = lbl_from_cat(lbl)
    vu.show_n_images([img[:,:,modality],lbl, show_lable_on_image4(img[:,:,modality],lbl)],
                    titles = [img_type[modality], 'Label', 'Label on '+ img_type[modality]]);

# %%
def show_lable(lbl):
    vu.show_n_images([lbl[:,:,k] for k in range(4)]+[lbl_from_cat(lbl)],
                 titles = label_type_shrt + ['Label'])

# %%
def show_pred_im_lable(im, lb, pred):
    vu.show_n_images([im[:,:,1], lb[:,:], 
                   show_lable_on_image4(im[:,:,1], lb[:,:]),
                  show_lable_on_image4(im[:,:,1], pred[:,:])],
                 titles=['Flair', 'Label', 'Label on T1', 'Prediction on Flair'])

# %%
def show_pred_im(im, pred):
    vu.show_n_images([im[:,:,1], 
                   im[:,:,0],pred,
                  show_lable_on_image4(im[:,:,1], pred[:,:])],
                 titles=['Flair','T1', 'Pred',  'Prediction on Flair'])

# %% [markdown]
# ## Read image description files
# In the preprocessing notebook, all files where saved as numpy.
#
# Some statistics on the labels were collected, to assist the training phase.

# %%
df_train= pd.read_csv('df_train.csv')
df_test= pd.read_csv('df_test.csv')
df_val= pd.read_csv('df_val.csv')

# %%
# Show distributin in train
df_train[['lab' +str(i) for i in range(1,4)]].sum().plot(kind='bar', color=my_colors,
                                                   title='Lable distribution in Train data')
# Out:
# <AxesSubplot:title={'center':'Lable distribution in Train data'}>

# %%
# show distribution in testdata
df_test[['lab' +str(i) for i in range(1,4)]].sum().plot(kind='bar', color=my_colors,
                                                   title='Lable distribution in Test data')
# Out:
# <AxesSubplot:title={'center':'Lable distribution in Test data'}>

# %% [markdown]
# ## Build Train generator

# %%
def get_numpy_img_lbl(img_id = 'BraTS19_TCIA10_449_1', np_dir=NUMPY_DIR):
    img=np.load(os.path.join(np_dir, img_id+'.npy'))
    lbl=np.load(os.path.join(np_dir, img_id+'_lbl.npy'))
    return img,lbl

# %%
def get_random_img(axis=0, df=df_train, np_dir=NUMPY_DIR):
    
    ind = randrange(len(df))
    img_id= df.iloc[ind].id
    img,lbl = get_numpy_img_lbl(img_id, np_dir=NUMPY_DIR)
        
    if (axis==0):
        x = randrange(df.iloc[ind].rmin, df.iloc[ind].rmax+1)
        return img[ x,:,:, :], lbl[x,:,:]

    im = np.zeros((240,240,4),dtype=np.float32)    
    lb = np.zeros((240,240),dtype=np.int)
        
    if (axis==1):
        y = randrange(df.iloc[ind].cmin, df.iloc[ind].cmax+1)
        im[40:40+155,:,:]=img[:, y,:, :]
        lb[40:40+155,:]=lbl[:, y,:]
        return im,lb
    
    if (axis == 2):
        z = randrange(df.iloc[ind].zmin, df.iloc[ind].zmax+1)
        im[40:40+155,:,:]=img[:,:, z, :]
        lb[40:40+155,:]=lbl[:,:,z]
        return im,lb
    return None

# %%
img,lbl = get_random_img(2)
show_img_lable(img, lbl)

# %% [markdown]
# Function randomly selects a 2D image that includes the given label

# %%
def get_img_for_label(lab=2, axis=0, df=df_train,np_dir = NUMPY_DIR):
    
    img_id= random.choice(df[df['lab'+str(lab)] > 0].id.values)
    
    img,lbl = get_numpy_img_lbl(img_id, np_dir)
    ind = np.where(lbl==lab)
    k = random.randrange(len(ind[0]))
    
    if (axis==0):        
        return img[ind[0][k],:,:] , lbl[ind[0][k],:,:]
        
    lb = np.zeros((240,240),dtype=np.int)
    im = np.zeros((240,240,4),dtype=np.float32)
    
    if (axis==1):
        im[40:40+155,:,:]=img[:, ind[1][k],:,:]
        lb[40:40+155,:]=lbl[:, ind[1][k],:]
        return im,lb
    
    if (axis == 2):
        im[40:40+155,:,:]=img[:, :, ind[2][k],:]
        lb[40:40+155,:]=lbl[:,:,ind[2][k]]
        return im,lb
    return None

# %%
img,lbl = get_img_for_label(1,1)
show_img_lable(img, lbl)

# %%
img,lbl = get_img_for_label(3,0)
show_img_lable(img, lbl)

# %%
img,lbl = get_img_for_label(2,2)
show_img_lable(img, lbl)

# %%
img,lbl = get_img_for_label(1,0)
show_img_lable(img, lbl)

# %%
def lbl_from_cat(cat_lbl):
    
    lbl=0
    if (len(cat_lbl.shape)==3):
        for i in range(1,4):
            lbl = lbl + cat_lbl[:,:,i]*i
    elif (len(cat_lbl.shape)==4):
        for i in range(1,4):
            lbl = lbl + cat_lbl[:,:,:,i]*i
    else:
        print('Error in lbl_from_cat', cat_lbl.shape)
        return None
    return lbl

# %% [markdown]
# For test we will create batch from few test images. only planes with lables >0 will be included.

# %%
def normalize_3D_image(img):
    for z in range(img.shape[0]):
        for k in range(4):
            if (img[z,:,:,k].max()>0):
                img[z,:,:,k] /= img[z,:,:,k].max()
    return img

# %%
def normalize_2D_image(img):

        for c in range(4):
            if (img[:,:,c].max()>0):
                img[:,:,c] = img[:,:,c]/img[:,:,c].max()
        return img

# %% [markdown]
# Function returns all z-planes of the image that have non-zerolable

# %%
def get_img_batch(row, np_dir=NUMPY_DIR):
    
    im,lb = get_numpy_img_lbl(row['id'], np_dir)
    
    n_im = row['rmax']-row['rmin']
    rmin=row['rmin']
    rmax=row['rmax']
    
    return normalize_3D_image(im[rmin:rmax]), np_utils.to_categorical(lb[rmin:rmax],4)

# %%
im, lb = get_img_batch(df_test.iloc[0])
im.shape, lb.shape
show_img_lable(im[6], lb[6])

# %%
i=15
show_lable(lb[i])

# %% [markdown]
# Get images with non-zero labels from all raws of given data frame

# %%
def get_df_img_batch(df_batch, np_dir=NUMPY_DIR):
    
        n_images = (df_batch.rmax - df_batch.rmin).sum()
        b_images = np.zeros((n_images, 240, 240, 4), np.float32)
        b_label = np.zeros((n_images, 240, 240, 4), np.int8)    
        ind=0
        for index, row in df_batch.iterrows():
 
            b_im, b_lb = get_img_batch(row, np_dir)
            n_im = b_im.shape[0]
            b_images[ind:ind+n_im] = b_im
            b_label[ind:ind+n_im] = b_lb
            ind+=n_im
               
        return b_images, b_label

# %%
im, lb = get_df_img_batch(df_test.iloc[0:3])
show_img_lable(im[100],lb[100])

# %% [markdown]
# Generator for test images
#
# Test the generator,takes
# ```
# CPU times: user 640 ms, sys: 1.3 s, total: 1.94 s
# Wall time: 2.72 s
# ```
# 3 images, ~251 planes

# %%
from keras.utils import np_utils
def generate_im_test_batch(n_images = 3, batch_size=300, df = df_test, np_dir=NUMPY_DIR):

    while 1:
         
        df_batch = df.sample(n_images)
        b_images, b_label = get_df_img_batch(df_batch, np_dir)                    
        b_images, b_label = shuffle(b_images, b_label)
        if (batch_size > 0):
            b_images = b_images[0:batch_size]
            b_label = b_label[0:batch_size]
            
        yield b_images, b_label

# %%
# %%time
gen_test_im = generate_im_test_batch(5)
imtest,lbtest = next(gen_test_im)
imtest.shape, lbtest.shape
# Out:
# CPU times: user 1.16 s, sys: 927 ms, total: 2.09 s
# Wall time: 2.21 s
# ((300, 240, 240, 4), (300, 240, 240, 4))

# %%
show_img_lable(imtest[100], lbtest[100])

# %%
ind=[6,8]
for i in ind:show_img_lable(imtest[i], lbtest[i])

# %% [markdown]
# Test the faster generator. Takes:
# ```
# CPU times: user 1.58 s, sys: 6.29 s, total: 7.87 s
# Wall time: 12.4 s
# ```
# for 32 batch size

# %%
#***
from keras.utils import np_utils
def generate_faste_train_batch(batch_size = 12, df = df_train ,np_dir=NUMPY_DIR):

    batch_images = np.zeros((batch_size, 240, 240, 4), np.float32)
    batch_label = np.zeros((batch_size, 240, 240, 4), np.int8)

    # lab1 22%
    # lab2 58%
    # lab3 18%

    while 1:

        df_batch = df.sample(3)
        b_images, b_label = get_df_img_batch(df_batch, np_dir)
        b_images, b_label = shuffle(b_images, b_label)
        batch_images[0:batch_size//2]=b_images[0:batch_size//2]
        batch_label[0:batch_size//2]=b_label[0:batch_size//2]

        i=batch_size//2
        # lab 1
        nim = batch_size//4
        for j in range(nim):
            im,lbl = get_img_for_label(lab=1, axis=random.choice([0,1,2]), df=df)
            batch_images[i] = normalize_2D_image(im)
            batch_label[i] = np_utils.to_categorical(lbl, 4)
            i+=1

        # lab 3
        nim = batch_size//4
        for j in range(nim):
            im,lbl = get_img_for_label(lab=3, axis=random.choice([0,1,2]), df=df)
            batch_images[i] = normalize_2D_image(im)
            batch_label[i] = np_utils.to_categorical(lbl, 4)
            i+=1

        batch_images, batch_label = shuffle(batch_images, batch_label)

        yield batch_images, batch_label
#

# %%
# %%time
gen_train_fast = generate_faste_train_batch(batch_size=16)
bimg,blbl = next(gen_train_fast)
bimg.shape, blbl.shape
# Out:
# CPU times: user 903 ms, sys: 1.61 s, total: 2.51 s
# Wall time: 2.68 s
# ((16, 240, 240, 4), (16, 240, 240, 4))

# %%
plt.imshow(normalize_2D_image(bimg[8]))

# %% [markdown]
# Slower train batch, but more ballanced in labels,

# %% [markdown]
# Define train generator and test that it works correctly.
# > Takes:
# CPU times:
# user 2.52 s, sys: 12 s, total: 14.5 s
# Wall time: 29.2 s
# > for batch size 32

# %%
#***

def generate_train_batch(batch_size = 12, df = df_train):
    
    batch_images = np.zeros((batch_size, 240, 240, 4), np.float32)
    batch_label = np.zeros((batch_size, 240, 240, 1), np.int8)
    
    # lab1 22%
    # lab2 58%
    # lab3 18%

    while 1:
         
        i = 0
        
        # lab 1
        nim = batch_size//4
        for j in range(nim):
            im,lbl = get_img_for_label(lab=1, axis=random.choice([0,1,2]), df=df)
            batch_images[i] = im/im.max()
            batch_label[i,:,:,0] = lbl
            i+=1
            
        
        # lab 2
        nim = batch_size//2
        for j in range(nim):
            im,lbl = get_img_for_label(lab=2, axis=random.choice([0,1,2]), df=df)
            batch_images[i] = im/im.max()
            batch_label[i,:,:,0] = lbl
            i+=1
            
        # lab 3
        nim = batch_size//4
        for j in range(nim):
            im,lbl = get_img_for_label(lab=3, axis=random.choice([0,1,2]), df=df)
            batch_images[i] = im/im.max()
            batch_label[i,:,:,0] = lbl
            i+=1

        # The rest
        nim = batch_size - i
        for j in range(nim):
            im,lbl = get_random_img(axis=random.choice([0,1,2]), df=df)
            batch_images[i] = im/im.max()
            batch_label[i,:,:,0] = lbl
            i+=1
                    
        batch_images, batch_label = shuffle(batch_images, batch_label)
            
        yield batch_images, np_utils.to_categorical(batch_label, 4)

# %%
# %%time
gen_train = generate_train_batch(batch_size=16)
bimg,blbl = next(gen_train)
bimg.shape, blbl.shape
# Out:
# CPU times: user 541 ms, sys: 2.15 s, total: 2.69 s
# Wall time: 3.15 s
# ((16, 240, 240, 4), (16, 240, 240, 4))

# %%
show_img_lable(bimg[i], blbl[i])

# %% [markdown]
# Test the generator
# ```
# CPU times: user 2.53 s, sys: 12.4 s, total: 14.9 s
# Wall time: 24.7 s
# ```

# %%
# %%time
gen_test = generate_train_batch(36,df_test)
bimg,blbl = next(gen_test)
bimg.shape, blbl.shape
# Out:
# CPU times: user 1.22 s, sys: 4.15 s, total: 5.38 s
# Wall time: 5.75 s
# ((36, 240, 240, 4), (36, 240, 240, 4))

# %%
i=6
show_img_lable(bimg[i], blbl[i])

# %% [markdown]
# ## define Base Unet Model

# %%
import tensorflow as tf
from keras import backend as K

from keras.models import Model, load_model
from keras.layers import Input, BatchNormalization, Activation, Dense, Dropout
from keras.layers.core import Lambda, RepeatVector, Reshape
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D, GlobalMaxPool2D
from keras.layers import Input, UpSampling2D
from keras.layers.merge import concatenate, add
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# %%
IMG_HEIGHT = 240
IMG_WIDTH = 240
IMG_CHANNELS = 4

# %%
import model_unet
reload(model_unet)
# Out:
# <module 'model_unet' from '/Users/nathansimms/PycharmProjects/cmpt340-brain-tumor-detection2/model_unet.py'>

# %%
model = model_unet.unet(IMG_HEIGHT,IMG_WIDTH,IMG_CHANNELS)

# %%
# custom loss function provider
# https://github.com/Mehrdad-Noori/Brain-Tumor-Segmentation/blob/master/loss.py
import tensorflow.keras.backend as K
from tensorflow.keras.losses import categorical_crossentropy
def generalized_dice(y_true, y_pred):

    """
    Generalized Dice Score
    https://arxiv.org/pdf/1707.03237

    """
    y_true = tf.cast(y_true, tf.float32)
    y_true    = K.reshape(y_true,shape=(-1,4))
    y_pred    = K.reshape(y_pred,shape=(-1,4))
    sum_p     = K.sum(y_pred, -2)
    sum_r     = K.sum(y_true, -2)
    sum_pr    = K.sum(y_true * y_pred, -2)
    weights   = K.pow(K.square(sum_r) + K.epsilon(), -1)
    generalized_dice = (2 * K.sum(weights * sum_pr)) / (K.sum(weights * (sum_r + sum_p)))

    return generalized_dice

def generalized_dice_loss(y_true, y_pred):
    return 1-generalized_dice(y_true, y_pred)

def custom_loss(y_true, y_pred):

    """
    The final loss function consists of the summation of two losses "GDL" and "CE"
    with a regularization term.
    """

    return generalized_dice_loss(y_true, y_pred) + 1.25 * categorical_crossentropy(y_true, y_pred)


model.compile(optimizer = Adam(lr = 0.0001), loss = "categorical_crossentropy",
              metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 240, 240, 4) 0
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 240, 240, 64) 2368        input_4[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 240, 240, 64) 36928       conv2d_69[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 120, 120, 64) 0           conv2d_70[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 120, 120, 128 73856       max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 120, 120, 128 147584      conv2d_71[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 60, 60, 128)  0           conv2d_72[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 60, 60, 256)  295168      max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 60, 60, 256)  590080      conv2d_73[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 30, 30, 256)  0           conv2d_74[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 30, 30, 512)  1180160     max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 30, 30, 512)  2359808     conv2d_75[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 30, 30, 512)  0           conv2d_76[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 15, 15, 512)  0           dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 15, 15, 1024) 4719616     max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 15, 15, 1024) 9438208     conv2d_77[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 15, 15, 1024) 0           conv2d_78[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_12 (UpSampling2D) (None, 30, 30, 1024) 0           dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 30, 30, 512)  2097664     up_sampling2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 30, 30, 1024) 0           dropout_6[0][0]
#                                                                  conv2d_79[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 30, 30, 512)  4719104     concatenate_12[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 30, 30, 512)  2359808     conv2d_80[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_13 (UpSampling2D) (None, 60, 60, 512)  0           conv2d_81[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 60, 60, 256)  524544      up_sampling2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 60, 60, 512)  0           conv2d_74[0][0]
#                                                                  conv2d_82[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 60, 60, 256)  1179904     concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 60, 60, 256)  590080      conv2d_83[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_14 (UpSampling2D) (None, 120, 120, 256 0           conv2d_84[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 120, 120, 128 131200      up_sampling2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 120, 120, 256 0           conv2d_72[0][0]
#                                                                  conv2d_85[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 120, 120, 128 295040      concatenate_14[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 120, 120, 128 147584      conv2d_86[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_15 (UpSampling2D) (None, 240, 240, 128 0           conv2d_87[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 240, 240, 64) 32832       up_sampling2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 240, 240, 128 0           conv2d_70[0][0]
#                                                                  conv2d_88[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 240, 240, 64) 73792       concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 240, 240, 64) 36928       conv2d_89[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 240, 240, 4)  260         conv2d_90[0][0]
# ==================================================================================================
# Total params: 31,032,516
# Trainable params: 31,032,516
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# %%time
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

earlystopper = EarlyStopping(patience=8, verbose=1)
checkpointer = ModelCheckpoint(filepath = 'model_unet_4ch.hdf5',
                               verbose=1,
                               save_best_only=True, save_weights_only = True)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                              patience=5, min_lr=0.000001, verbose=1,  cooldown=1)
# Out:
# CPU times: user 50 µs, sys: 20 µs, total: 70 µs
# Wall time: 75.1 µs

# %%
from keras.preprocessing.image import ImageDataGenerator
b_images, b_label = get_df_img_batch(df_train, NUMPY_DIR)

v_images, v_label = get_df_img_batch(df_test, NUMPY_DIR)


data_gen_args = dict(featurewise_center=True,
                     featurewise_std_normalization=True,
                     rotation_range=90,
                     width_shift_range=0.1,
                     height_shift_range=0.1,
                     horizontal_flip=True,
                     vertical_flip=True,
                     zoom_range=0.2)

image_datagen = ImageDataGenerator(**data_gen_args)
validation_datagen= ImageDataGenerator(**data_gen_args)
# Provide the same seed and keyword arguments to the fit and flow methods

seed = 1
image_datagen.fit(b_images, augment=True, seed=seed)
validation_datagen.fit(v_images, augment=True, seed=seed)
image_generator = image_datagen.flow(
    b_images,
    y=b_label,
    batch_size=10,
)


validation_datagen = validation_datagen.flow(
    v_images,
    y=v_label,
    batch_size=10,
)



# combine generators into one which yields image and masks
# train_generator = zip(image_generator, mask_generator)

# %%
# %%time

history = model.fit(image_generator,
                    validation_data = validation_datagen, validation_steps=5,steps_per_epoch=5,
                              epochs=30,
                    callbacks=[earlystopper, checkpointer, reduce_lr])
# Out:
# Epoch 1/30
# 5/5 [==============================] - 68s 14s/step - loss: 1.1954 - accuracy: 0.5651 - val_loss: 0.3251 - val_accuracy: 0.9562
#
# Epoch 00001: val_loss improved from inf to 0.32512, saving model to model_unet_4ch.hdf5
# Epoch 2/30
# 5/5 [==============================] - 68s 14s/step - loss: 0.3729 - accuracy: 0.9382 - val_loss: 0.3214 - val_accuracy: 0.9674
#
# Epoch 00002: val_loss improved from 0.32512 to 0.32141, saving model to model_unet_4ch.hdf5
# Epoch 3/30
# 5/5 [==============================] - 74s 15s/step - loss: 0.3138 - accuracy: 0.9656 - val_loss: 0.2157 - val_accuracy: 0.9671
#
# Epoch 00003: val_loss improved from 0.32141 to 0.21575, saving model to model_unet_4ch.hdf5
# Epoch 4/30
# 5/5 [==============================] - 74s 16s/step - loss: 0.2117 - accuracy: 0.9696 - val_loss: 0.1495 - val_accuracy: 0.9750
#
# Epoch 00004: val_loss improved from 0.21575 to 0.14949, saving model to model_unet_4ch.hdf5
# Epoch 5/30
# 5/5 [==============================] - 76s 16s/step - loss: 0.1682 - accuracy: 0.9721 - val_loss: 0.1534 - val_accuracy: 0.9719
#
# Epoch 00005: val_loss did not improve from 0.14949
# Epoch 6/30
# 5/5 [==============================] - 77s 16s/step - loss: 0.1351 - accuracy: 0.9738 - val_loss: 0.1559 - val_accuracy: 0.9722
#
# Epoch 00006: val_loss did not improve from 0.14949
# Epoch 7/30
# 5/5 [==============================] - 86s 18s/step - loss: 0.1562 - accuracy: 0.9715 - val_loss: 0.1607 - val_accuracy: 0.9697
#
# Epoch 00007: val_loss did not improve from 0.14949
# Epoch 8/30
# 5/5 [==============================] - 85s 18s/step - loss: 0.1265 - accuracy: 0.9766 - val_loss: 0.1510 - val_accuracy: 0.9710
#
# Epoch 00008: val_loss did not improve from 0.14949
# Epoch 9/30
# 5/5 [==============================] - 90s 19s/step - loss: 0.1218 - accuracy: 0.9757 - val_loss: 0.1343 - val_accuracy: 0.9740
#
# Epoch 00009: val_loss improved from 0.14949 to 0.13433, saving model to model_unet_4ch.hdf5
# Epoch 10/30
# 5/5 [==============================] - 90s 19s/step - loss: 0.1147 - accuracy: 0.9767 - val_loss: 0.1535 - val_accuracy: 0.9686
#
# Epoch 00010: val_loss did not improve from 0.13433
# Epoch 11/30
# 5/5 [==============================] - 88s 18s/step - loss: 0.1237 - accuracy: 0.9724 - val_loss: 0.1373 - val_accuracy: 0.9740
#
# Epoch 00011: val_loss did not improve from 0.13433
# Epoch 12/30
# 5/5 [==============================] - 84s 18s/step - loss: 0.1222 - accuracy: 0.9748 - val_loss: 0.1603 - val_accuracy: 0.9665
#
# Epoch 00012: val_loss did not improve from 0.13433
# Epoch 13/30
# 5/5 [==============================] - 89s 19s/step - loss: 0.1223 - accuracy: 0.9726 - val_loss: 0.1311 - val_accuracy: 0.9734
#
# Epoch 00013: val_loss improved from 0.13433 to 0.13113, saving model to model_unet_4ch.hdf5
# Epoch 14/30
# 5/5 [==============================] - 93s 19s/step - loss: 0.1257 - accuracy: 0.9727 - val_loss: 0.1271 - val_accuracy: 0.9732
#
# Epoch 00014: val_loss improved from 0.13113 to 0.12714, saving model to model_unet_4ch.hdf5
# Epoch 15/30
# 5/5 [==============================] - 93s 20s/step - loss: 0.1116 - accuracy: 0.9760 - val_loss: 0.1308 - val_accuracy: 0.9721
#
# Epoch 00015: val_loss did not improve from 0.12714
# Epoch 16/30
# 5/5 [==============================] - 86s 18s/step - loss: 0.1332 - accuracy: 0.9687 - val_loss: 0.1377 - val_accuracy: 0.9708
#
# Epoch 00016: val_loss did not improve from 0.12714
# Epoch 17/30
# 5/5 [==============================] - 84s 18s/step - loss: 0.1256 - accuracy: 0.9708 - val_loss: 0.1343 - val_accuracy: 0.9731
#
# Epoch 00017: val_loss did not improve from 0.12714
# Epoch 18/30
# 5/5 [==============================] - 89s 19s/step - loss: 0.1323 - accuracy: 0.9710 - val_loss: 0.1420 - val_accuracy: 0.9690
#
# Epoch 00018: val_loss did not improve from 0.12714
# Epoch 19/30
# 5/5 [==============================] - 88s 18s/step - loss: 0.1214 - accuracy: 0.9724 - val_loss: 0.1383 - val_accuracy: 0.9712
#
# Epoch 00019: val_loss did not improve from 0.12714
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 20/30
# 5/5 [==============================] - 91s 19s/step - loss: 0.1239 - accuracy: 0.9687 - val_loss: 0.1317 - val_accuracy: 0.9724
#
# Epoch 00020: val_loss did not improve from 0.12714
# Epoch 21/30
# 5/5 [==============================] - 80s 16s/step - loss: 0.1348 - accuracy: 0.9673 - val_loss: 0.1489 - val_accuracy: 0.9673
#
# Epoch 00021: val_loss did not improve from 0.12714
# Epoch 22/30
# 5/5 [==============================] - 95s 20s/step - loss: 0.1137 - accuracy: 0.9740 - val_loss: 0.1424 - val_accuracy: 0.9707
#
# Epoch 00022: val_loss did not improve from 0.12714
# Epoch 00022: early stopping
# CPU times: user 4h 40min 23s, sys: 11min 41s, total: 4h 52min 5s
# Wall time: 30min 51s

# %%
vu.drow_history(history)
with open('model_history.txt','w') as data:
      data.write(str(history.history))
vu.drow_accuracy(history)
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
model.save_weights('model_unet_ce.hdf5')

# %%
model.load_weights('model_unet_4ch.hdf5')

# %% [markdown]
# ## Predict with trained model

# %% [markdown]
# Function converts probabilities to labels

# %%
def get_pred(img, threshold=0.5):
    out_img=img.copy()
    out_img=np.where(out_img>threshold, 1,0)
    return out_img

# %%
def prediction_from_probabily_3D(img):
    
    int_image = get_pred(img)
    return lbl_from_cat(int_image)

# %%
def get_prediction_for_batch(pred_batch, threshold=0.5):
    
    out_batch = np.zeros((pred_batch.shape[0], 240, 240),dtype=np.int)
    
    for j in range(pred_batch.shape[0]):
        pred = get_prediction(pred_batch[j])
        if (pred.sum()>0):
            print(j, np.unique(pred , return_counts=True))
        out_batch[j] = lbl_from_cat(get_prediction(pred_batch[j]))
    return out_batch

# %%
def get_label_from_pred_batch(labels_batch):
    
    batch = np.zeros((labels_batch.shape[0], 240, 240), np.uint8)
     
    for j in range(labels_batch.shape[0]):
        batch[j]=get_pred(labels_batch[j,:,:,0])+\
                get_pred(labels_batch[j,:,:,1])*2+\
        get_pred(labels_batch[j,:,:,2])*4

    return batch

# %%
def predict_3D_img_prob(np_file):
    
    np_img = np.load(np_file)
    for_pred_img = np.zeros((155, 240, 240, 4), np.float32)

    # Normalize image
    for_pred_img = normalize_3D_image(np_img)

    mdl_pred_img =  model.predict(for_pred_img)

    #pred_label = prediction_from_probabily_3D(mdl_pred_img)

    return mdl_pred_img

# %% [markdown]
# ## Predict on Test images

# %%
df_test.head()
# Out:
#   Grade                    id     lab0   lab1    lab2   lab3  rmin  rmax  \
# 0   LGG  BraTS19_TCIA09_254_1  8732567  77985  117448      0    29   106
# 1   HGG   BraTS19_TMC_27374_1  8806850  20043   73565  27542    31    99
# 2   HGG  BraTS19_TCIA02_135_1  8846153   3614   44701  33532    68   128
# 3   HGG  BraTS19_TCIA02_491_1  8765377  15826   83088  63709    34   122
# 4   LGG  BraTS19_TCIA10_276_1  8882310  14413   31183     94    51   106
#
#    cmin  cmax  zmin  zmax
# 0    83   191    54   128
# 1    85   171   121   177
# 2   128   198    70   118
# 3    69   196    51   128
# 4    44   118    85   131

# %%
img_id = 'BraTS19_2013_18_1'
im,lb = get_numpy_img_lbl(img_id = 'BraTS19_2013_18_1')
im.shape,lb.shape
# Out:
# ((155, 240, 240, 4), (155, 240, 240))

# %%
nimg = os.path.join(NUMPY_DIR, img_id+'.npy')
pred_stats = predict_3D_img_prob(nimg)
pred_stats.shape
# Out:
# (155, 240, 240, 4)

# %%
pred = prediction_from_probabily_3D(pred_stats)
pred.shape
# Out:
# (155, 240, 240)

# %%
x = np.unique(pred)
print(x)
# Out:
# [0]

# %% [markdown]
# View predicted probabilities, and the resulted labels

# %%
ind=[70,80,90]
for i in ind:
    show_lable(pred_stats[i])
    show_lable(get_pred(pred_stats[i]))
    show_pred_im_lable(im[i], lb[i], pred[i])

# %% [markdown]
# ## Predict all test images to calculate IOU

# %% [markdown]
# Check that its all working

# %%
img_id = 'BraTS19_2013_18_1'
im,lb = get_numpy_img_lbl(img_id = 'BraTS19_2013_18_1')
im.shape,lb.shape

nimg = os.path.join(NUMPY_DIR, img_id+'.npy')
pred_stats = predict_3D_img_prob(nimg)
pred_stats.shape

pred = prediction_from_probabily_3D(pred_stats)
pred.shape
# Out:
# (155, 240, 240)

# %%
show_pred_im_lable(im[100], lb[100], pred[100])

# %%
for index, row in df_test.iterrows():

    img_id = row['id']
    im,lb = get_numpy_img_lbl(img_id = 'BraTS19_2013_18_1')

    nimg = os.path.join(NUMPY_DIR, img_id+'.npy')
    pred_stats = predict_3D_img_prob(nimg)

    pred = prediction_from_probabily_3D(pred_stats)

    out_img = os.path.join(TEST_PRED_NUMPY_DIR, img_id+'_pred.npy')

    np.save(out_img, pred)

# %% [markdown]
# ## Predict all validation image

# %%
df_val.head()
# Out:
#                      id  lab0  lab1  lab2  lab3
# 0   BraTS19_CBICA_ARR_1     0     0     0     0
# 1   BraTS19_CBICA_BHN_1     0     0     0     0
# 2    BraTS19_MDA_1060_1     0     0     0     0
# 3     BraTS19_MDA_907_1     0     0     0     0
# 4  BraTS19_TCIA02_294_1     0     0     0     0

# %%
img_id='BraTS19_TCIA13_643_1'
nimg = os.path.join(VALIDATION_NUMPY_DIR, img_id+'.npy')
im = np.load(nimg)
pred_stats = predict_3D_img_prob(nimg)
pred = prediction_from_probabily_3D(pred_stats)
show_pred_im(im[100], pred[100])

# %%
for index, row in df_val.iterrows():

    img_id = row['id']

    nimg = os.path.join(VALIDATION_NUMPY_DIR, img_id+'.npy')
    pred_stats = predict_3D_img_prob(nimg)

    pred = prediction_from_probabily_3D(pred_stats)

    out_img = os.path.join(VALIDATION_PRED_NUMPY_DIR, img_id+'_pred.npy')
    np.save(out_img, pred)
    
    pred = np.where(pred==3,4, pred)
    out_nii = os.path.join(VALIDATION_PRED_NII_DIR, img_id+'.nii.gz')

    sitk_img = sitk.GetImageFromArray(pred)
    sitk.WriteImage(sitk_img , out_nii)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-369-60991b453030> in <module>
#       9
#      10     out_img = os.path.join(VALIDATION_PRED_NUMPY_DIR, img_id+'_pred.npy')
# ---> 11     np.save(out_img, pred)
#      12
#      13     pred = np.where(pred==3,4, pred)
#
# <__array_function__ internals> in save(*args, **kwargs)
#
# ~/PycharmProjects/pythonProject/venv/lib/python3.8/site-packages/numpy/lib/npyio.py in save(file, arr, allow_pickle, fix_imports)
#     526     with file_ctx as fid:
#     527         arr = np.asanyarray(arr)
# --> 528         format.write_array(fid, arr, allow_pickle=allow_pickle,
#     529                            pickle_kwargs=dict(fix_imports=fix_imports))
#     530
#
# ~/PycharmProjects/pythonProject/venv/lib/python3.8/site-packages/numpy/lib/format.py in write_array(fp, array, version, allow_pickle, pickle_kwargs)
#     673     else:
#     674         if isfileobj(fp):
# --> 675             array.tofile(fp)
#     676         else:
#     677             for chunk in numpy.nditer(
#
# OSError: 8928000 requested and 4879360 written
